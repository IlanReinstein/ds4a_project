# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
import os

# %%
files = os.listdir('data/raw')

# %%
tables = {f: pd.read_csv('data/raw/' + f) for f in files}

# %%
tables['Rotacion de Pronostico.csv'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Año/Mes              476 non-null    float64
#  1   Canal distribución   476 non-null    object
#  2   Mat:Concepto Diseño  476 non-null    object
#  3   Mat:Mes Venta        476 non-null    object
#  4   Mat:Mundo            476 non-null    object
#  5   Mat:SubLinea         476 non-null    object
#  6   Mat:Tipo Articulo    476 non-null    object
#  7   Mat:Tipo de Negocio  476 non-null    object
#  8   Talla                476 non-null    object
#  9   Material             476 non-null    object
#  10  Und. Pronóstico      476 non-null    int64
#  11  Und. Vendidas        476 non-null    int64
#  12  % Rotación           448 non-null    float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 48.5+ KB

# %%
pedidos = tables['Base de datos proyecto Analitica.csv']
pedidos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162037 entries, 0 to 162036
# Data columns (total 61 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   D. Clase Fact.      162037 non-null  object
#  1   # Factura           162037 non-null  int64
#  2   # Pedido            162037 non-null  int64
#  3   Sociedad            162037 non-null  int64
#  4   C. Org. Vtas        162037 non-null  int64
#  5   D. Org. Vtas        162037 non-null  object
#  6   C. Canal            162037 non-null  int64
#  7   D. Canal            162037 non-null  object
#  8   C. Centro           162037 non-null  object
#  9   D. Centro           162037 non-null  object
#  10  Ciudad              162037 non-null  object
#  11  C. Of. Vtas         162037 non-null  object
#  12  D. Of. Vtas         162037 non-null  object
#  13  F. Factura          162037 non-null  object
#  14  Año Factura         162037 non-null  int64
# ...

# %%
tables['Enero Pronostico Consolidado Final 01062020.csv'].head()
# Out:
#        Temporada Destino  Referencia           Color Talla Tipo Articulo  \
# 0  2020/01 Enero   Todos   5110366.0  Blanco 10-0000    28       CALZADO
# 1  2020/01 Enero   Todos   5110366.0  Blanco 10-0000    29       CALZADO
# 2  2020/01 Enero   Todos   5110366.0  Blanco 10-0000    30       CALZADO
# 3  2020/01 Enero   Todos   5110366.0  Blanco 10-0000    31       CALZADO
# 4  2020/01 Enero   Todos   5110366.0  Blanco 10-0000    32       CALZADO
#
#   Valor Matriz Mundo Concepto Diseño  PVP Objetivo   Costo Objetivo   \
# 0     28  B001  Niño         Escolar      $ 85,900         $ 26,000
# 1     29  B001  Niño         Escolar      $ 85,900         $ 26,000
# 2     30  B001  Niño         Escolar      $ 85,900         $ 26,000
# 3     31  B001  Niño         Escolar      $ 85,900         $ 26,000
# 4     32  B001  Niño         Escolar      $ 85,900         $ 26,000
#
#    Oficina Ventas  Centro           Canal  Cantidad     Costo TT       PVP TT
# ...
