# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
files = os.listdir('data/raw')

# %%
tables = {f: pd.read_csv('data/raw/' + f) for f in files}

# %%
tables['Rotacion de Pronostico.csv']
# Out:
#      Año/Mes Canal distribución Mat:Concepto Diseño Mat:Mes Venta  \
# 0     1.2018    Tiendas Propias             ESCOLAR         ENERO
# 1     1.2018    Tiendas Propias             ESCOLAR         ENERO
# 2     1.2018    Tiendas Propias             ESCOLAR         ENERO
# 3     1.2018    Tiendas Propias             ESCOLAR         ENERO
# 4     1.2018    Tiendas Propias             ESCOLAR         ENERO
# ..       ...                ...                 ...           ...
# 471   1.2018    Tiendas Propias  PSYCHEDELIC NATURE         ENERO
# 472   1.2018    Tiendas Propias  PSYCHEDELIC NATURE         ENERO
# 473   1.2018    Tiendas Propias  PSYCHEDELIC NATURE         ENERO
# 474   1.2018    Tiendas Propias  PSYCHEDELIC NATURE         ENERO
# 475   1.2018    Tiendas Propias  PSYCHEDELIC NATURE         ENERO
#
#            Mat:Mundo Mat:SubLinea Mat:Tipo Articulo Mat:Tipo de Negocio Talla  \
# 0     BEBES-FEMENINO         MODA     OVERALL LARGO            NO LINEA    12
# ...

# %%
tables['Base de datos proyecto Analitica.csv'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162037 entries, 0 to 162036
# Data columns (total 61 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   D. Clase Fact.      162037 non-null  object
#  1   # Factura           162037 non-null  int64
#  2   # Pedido            162037 non-null  int64
#  3   Sociedad            162037 non-null  int64
#  4   C. Org. Vtas        162037 non-null  int64
#  5   D. Org. Vtas        162037 non-null  object
#  6   C. Canal            162037 non-null  int64
#  7   D. Canal            162037 non-null  object
#  8   C. Centro           162037 non-null  object
#  9   D. Centro           162037 non-null  object
#  10  Ciudad              162037 non-null  object
#  11  C. Of. Vtas         162037 non-null  object
#  12  D. Of. Vtas         162037 non-null  object
#  13  F. Factura          162037 non-null  object
#  14  Año Factura         162037 non-null  int64
# ...

# %%
tables['Enero Pronostico Consolidado Final 01062020.csv']
# Out:
#            Temporada Destino  Referencia           Color Talla  \
# 0      2020/01 Enero   Todos   5110366.0  Blanco 10-0000    28
# 1      2020/01 Enero   Todos   5110366.0  Blanco 10-0000    29
# 2      2020/01 Enero   Todos   5110366.0  Blanco 10-0000    30
# 3      2020/01 Enero   Todos   5110366.0  Blanco 10-0000    31
# 4      2020/01 Enero   Todos   5110366.0  Blanco 10-0000    32
# ...              ...     ...         ...             ...   ...
# 72722  2020/01 Enero   Todos   5205481.0    Indigo Medio    12
# 72723  2020/01 Enero   Todos   5205481.0    Indigo Medio    14
# 72724  2020/01 Enero   Todos   5205481.0    Indigo Medio    16
# 72725            NaN     NaN         NaN             NaN   NaN
# 72726            NaN     NaN         NaN             NaN   NaN
#
#         Tipo Articulo Valor Matriz Mundo Concepto Diseño  PVP Objetivo   \
# 0             CALZADO     28  B001  Niño         Escolar      $ 85,900
# ...
